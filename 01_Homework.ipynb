# %% [markdown]
# Brief Homework 1
# ----------------------
#
# In class, we looked at data and analysis around the death toll from Hurricane Maria. We ended the session looking at crime statistics from the FBI's Uniform Crime Reporting Program. Review that notebook before starting this assignment to refresh yourself on the syntax that R uses. The data we start with for this homework comes from the Major Cities Chiefs Association which has been surveying its members to get a sense of where crime is headed. Their report is here -- [MCCA Violent Crime Statistics](https://assets.documentcloud.org/documents/3023302/MCCA-Violent-Crime-Data-Midyear-2016-2015-8716.pdf).
#
# This little homework was part of a story by Tom Meagher and Gabe Dance at The Marshall Project. Have a look at thier [Crime in Context](https://www.themarshallproject.org/2016/08/18/crime-in-context) to see where these simple tools proved helpful. Read it over and take note of the kinds of statitics used in the story.
#
# The data we need is in a PDF table. PDF (the Portable Document Format) is really good for representing data to a printer -- creating a standard like this was a huge deal when PDF was introduced. Often, however, it becomes a vehicle for publishing data and then you start to see its weaknesses. Extracting data from a PDF will depend, first, on the kind of PDF it is. If you can "select" text from the document, you're in luck. There are several tools to help you get reasonably close to the data. If, on the other hand, your pages are essentially images, well, then you have to rely on "optical character recognition" programs that cluster black and white pixels, say, into letters and words and sentences.
#
# I used [Tabula](http://tabula.technology/) to pull the data from the Chiefs' report and convert it to something more usable, a CSV (comma separated values) file. CSV files are a popular format for tabular data. Each line in the file represents a different person or object or "entity." Measurements, or "attributes" on a given entity occupy one line in the file and are separated by commas. You can read more about the format [here](https://en.wikipedia.org/wiki/Comma-separated_values). [Download the data](https://www.dropbox.com/s/qjgc6xri89hg4ub/mcca.csv?dl=0) and have a look -- perhaps open it in your favorite spreadsheet program.
#
# To pull this data into R, we will again use the function `read.csv()`, but this time loading the data using a URL from github.com.

# %%
chiefs <- read.csv("https://github.com/cocteau/lede2018/raw/master/data/mcca.csv",as.is=TRUE)
head(chiefs)
# Out:
#   agency              hom16 hom15 rap16 rap15 rob16 rob15 agg16 agg15 non16
# 1 Albuquerque PD      34    25    156   199    753   861  1601  1608  125
# 2 Arlington PD        13     4    123   117    245   248   668   600   NA
# 3 Atlanta PD          57    45     72    72   1005  1003  1028  1064  161
# 4 Aurora PD           10     7    127   149    287   205   390   317   18
# 5 Austin PD           12     9    328   387    516   446  1114   942   NA
# 6 Baltimore County PD 16    14    141   134    583   652   823  1193   20
#   non15
# 1  NA
# 2  NA
# 3 161
# 4  15
# 5  NA
# 6  18

# %%
tail(chiefs)
# Out:
#    agency                   hom16 hom15 rap16 rap15 rob16 rob15 agg16 agg15
# 57 Tampa PD                 12    21     45    32    258   296   659   772
# 58 Tucson PD                11    16    221   213    537   516  1219   961
# 59 Tulsa PD                 30    27    185   170    459   426  1345  1176
# 60 Virginia Beach PD         8    12    102    75    131   126   136   129
# 61 Washington DC (Metro PD) 68    63    145   128   1491  1527  1102  1211
# 62 Wichita PD               10    13    183   165    289   329  1100   855
#    non16 non15
# 57 38    75
# 58 NA    NA
# 59 NA    NA
# 60 NA    NA
# 61 NA    NA
# 62 61    24

# %% [markdown]
# Again, "chiefs" is a data frame and `head()` and `tail()` give us a peak at the top and bottom. We can see how much there is using the command `dim()`.

# %%
dim(chiefs)
# Out:
# [1] 62 11

# %% [markdown]
# Which means 62 agencies, with 11 different attributes recorded for each.

# %% [markdown]
# Mid-year Crime Calculations
# ---------------------------
#
# That's enough background for one day. Let's look at the data. When the MCCA report appearaed over the summer, it generated some attention. [CNN](http://www.cnn.com/2016/07/25/politics/violent-crime-report-us-cities-homicides-rapes/), [Breitbart](http://www.breitbart.com/big-government/2016/07/26/survey-violent-crime-major-cities/), [The New York Times](http://www.nytimes.com/2016/05/14/us/murder-rates-cities-fbi.html) and a number of other outlets picked up the data and tried to draw some meaning from it. Have a read and see what you think.
#
# In the cell below, write a 3 sentence summary (or less) of what the data are, who collected them and why. With that completed, what kinds of questions do we want to ask about these data? Write down 5 questions.

# %% [markdown]
# **The data:**
#
#
#
# **My questions**

# %% [markdown]
# During his primary run, in a speech the RNC, Trump said that “Our president, who has used the pulpit of the presidency to divide us by race and color, has made America a more dangerous environment for everyone than frankly I have ever seen and anybody in this room has ever watched or seen.” This kicked off a wave of reporting about the safety of our cities. At the DNC in Philadelphia, Obama responded, “Donald Trump calls [America] ‘a divided crime scene’ that only he can fix. It doesn’t matter to him that illegal immigration and the crime rate are as low as they’ve been in decades…”
#
# How do we think about these conflicting impressions? We'll look at this question while learning a bit of R syntax (heck it's day 1).
#
# **Extracting data**. To try out your skills let's do a speed round of simple tasks. First, extract just the agency names from this table as a vector. Hint: You'll need to use the `$`. You can also use the `filter()` command and other verbs from dplyr2. Try them all out to get comfortable. The goal of this homework is to rehearse some of what we went over in class. I want you to be comfortable with both simple extractions like with the `$` and Pandas-like subsetting, together with the verbs from dplyr2.

# %%
# your one line here
chiefs$agency
# Out:
#  [1] "Albuquerque PD"                    "Arlington PD"
#  [3] "Atlanta PD"                        "Aurora PD"
#  [5] "Austin PD"                         "Baltimore County PD"
#  [7] "Baltimore PD"                      "Boston PD"
#  [9] "Charlotte-Mecklenburg PD"          "Chicago PD"
# [11] "Cincinnati PD"                     "Cleveland PD"
# [13] "Columbus Police"                   "Dallas PD"
# [15] "Denver PD"                         "El Paso PD"
# [17] "Fairfax County PD"                 "Fort Worth PD"
# [19] "Fresno PD"                         "Honolulu PD 2"
# [21] "Houston PD"                        "Indianapolis PD"
# [23] "Jacksonville Sheriff's Dept"       "Las Vegas Metropolitan PD"
# [25] "Long Beach PD"                     "Los Angeles County Sheriff's Dept"
# [27] "Los Angeles PD"                    "Louisville Metro PD"
# [29] "Memphis PD"                        "Mesa PD"
# [31] "Miami PD"                          "Miami-Dade PD"
# [33] "Milwaukee PD"                      "Montgomery Co PD"
# [35] "Nashville PD"                      "Nassau County PD 1"
# [37] "New Orleans PD"                    "New York City PD"
# [39] "Newark PD"                         "Oakland PD"
# [41] "Oklahoma City PD 2"                "Omaha NE PD"
# [43] "Orlando PD 3"                      "Philadelphia PD"
# [45] "Phoenix PD 4"                      "Pittsburgh PD"
# [47] "Prince George’s County PD"         "Raleigh PD"
# [49] "Sacramento PD"                     "Salt Lake City PD"
# [51] "San Antonio PD"                    "San Diego PD"
# [53] "San Francisco PD"                  "San Jose PD"
# [55] "Seattle PD"                        "St. Louis Metro PD"
# [57] "Tampa PD"                          "Tucson PD"
# [59] "Tulsa PD"                          "Virginia Beach PD"
# [61] "Washington DC (Metro PD)"          "Wichita PD"

# %%
library(dplyr)

# %% [markdown]
# ... and the vaues for homicides in 2016.

# %%
# your one line here
chiefs$hom16
# Out:
#  [1]  34  13  57  10  12  16 137  22  25 316  35  47  39  83  19   8   7  34  17
# [20]   8 158  61  59  90  15 110 134  54 106  11  27  37  54   8  34   3  67 161
# [39]  45  28  19  12  65 122  78  30  48   6  13   3  70  24  26  25  12  87  12
# [58]  11  30   8  68  10

# %% [markdown]
# **Computing crime rates**. We can compare the overall numbers of homicides in these 62 cities by adding or "sum"ing the columns for 2015 and 2016. Compute the total homicide count for 2015...

# %%
sum(chiefs$hom15)
# Out:
# [1] 2636

# %% [markdown]
# ... and then do it for for 2016.

# %%
# your one line here
sum(chiefs$hom16)
# Out:
# [1] 2980

# %% [markdown]
# To compare the overall change from 2015 to 2016, we might take the percentage change. That is the difference between homicides in 2016 and 2015 divided by the total in 2015. Use the two numbers above to compute this percent change...

# %%
# your one line here
(2980-2636)/2636
# Out:
# [1] 0.1305008

# %% [markdown]
# A big increase. Now, let's compute the rates of change for each agency. Rather than work on the crime categories separately, We will focuse on [violent crime](https://ucr.fbi.gov/crime-in-the-u.s/2011/crime-in-the-u.s.-2011/violent-crime/violent-crime). The FBI defines violent crime as the sum of homicides, rapes, robberies and aggravated assault. Let's use R to create these sums.
#
# We can add up the four crime categories as "vectors" -- meaning we can add up all four crime categories for each agency with a simple mathematical expression. Add up the data for 2016 for homicides, rapes, robberies and aggravated assaults.

# %%
# your one line here
chiefs$hom16+chiefs$rap16+chiefs$rob16+chiefs$agg16
# Out:
#  [1]  2544  1049  2162   814  1970  1563  4991  2066  3161  8920  1086  2625
# [13]  2027  4774  2210  1354   338  2169  1563   744 11593  3402  2409  3255
# [25]  1408  7082 14078  2342  4335   923  1922  2899  4383   786  3701   510
# [37]  2001 18120  1231  2921  1676  1105  1193  7374    NA  1143   820   736
# [49]  1716   770  5111  2644  2988  1919  1885  2776   974  1988  2019   377
# [61]  2806  1582

# %% [markdown]
# ... And  store it back in the original data frame using the "$" notation or `mutate()` as we did in class. Call the new variable `vc16` for "violent crime 2016"

# %%
# your code here
chiefs$vc16 <- chiefs$hom16+chiefs$rap16+chiefs$rob16+chiefs$agg16

# %% [markdown]
# Have a look at the top of the file to make sure your column has been added.

# %%
# your one line here
head(chiefs)
# Out:
#   agency              hom16 hom15 rap16 rap15 rob16 rob15 agg16 agg15 non16
# 1 Albuquerque PD      34    25    156   199    753   861  1601  1608  125
# 2 Arlington PD        13     4    123   117    245   248   668   600   NA
# 3 Atlanta PD          57    45     72    72   1005  1003  1028  1064  161
# 4 Aurora PD           10     7    127   149    287   205   390   317   18
# 5 Austin PD           12     9    328   387    516   446  1114   942   NA
# 6 Baltimore County PD 16    14    141   134    583   652   823  1193   20
#   non15 vc16
# 1  NA   2544
# 2  NA   1049
# 3 161   2162
# 4  15    814
# 5  NA   1970
# 6  18   1563

# %% [markdown]
# Now, do the same thing, but add a column for 2015 calling it `vc15` and have a look again.

# %%
# your code here
#
chiefs$vc15 <- chiefs$hom15+chiefs$rap15+chiefs$rob15+chiefs$agg15
head(chiefs)
# Out:
#   agency              hom16 hom15 rap16 rap15 rob16 rob15 agg16 agg15 non16
# 1 Albuquerque PD      34    25    156   199    753   861  1601  1608  125
# 2 Arlington PD        13     4    123   117    245   248   668   600   NA
# 3 Atlanta PD          57    45     72    72   1005  1003  1028  1064  161
# 4 Aurora PD           10     7    127   149    287   205   390   317   18
# 5 Austin PD           12     9    328   387    516   446  1114   942   NA
# 6 Baltimore County PD 16    14    141   134    583   652   823  1193   20
#   non15 vc16 vc15
# 1  NA   2544 2693
# 2  NA   1049  969
# 3 161   2162 2184
# 4  15    814  678
# 5  NA   1970 1784
# 6  18   1563 1993

# %% [markdown]
# We can now look at the change for each city. This is defined as the difference between 2016 and 2016 as a fraction of 2015's total. As with simple addition of columns, we can express more complicated arithmetic expressions in one go. Write out your one line to compute the relative change.

# %%
# your one line here
(chiefs$vc16-chiefs$vc15)/chiefs$vc15
# Out:
#  [1] -0.05532863  0.08255934 -0.01007326  0.20058997  0.10426009 -0.21575514
#  [7]  0.08241162 -0.04836481  0.21811175  0.23854485 -0.01985560 -0.07830056
# [13] -0.14000849  0.09949332  0.01376147  0.12833333  0.15358362  0.02070588
# [19]  0.18678815 -0.02490170  0.13656863  0.15049036 -0.01633320  0.19977884
# [25]  0.08141321  0.09138542  0.18471766  0.13414044  0.07755406 -0.09421001
# [31] -0.07239382 -0.08317521  0.00967519 -0.12276786  0.06106651  0.05590062
# [37]  0.21125908  0.01523980 -0.12880396 -0.07825813  0.09829620 -0.08450704
# [43] -0.06062992 -0.03582636          NA  0.08857143  0.07189542 -0.10462287
# [49] -0.06331878  0.19751166  0.27615481 -0.07065026 -0.13441483  0.12882353
# [55]  0.03231106 -0.01069138 -0.13113292  0.16529894  0.12229016  0.10233918
# [61] -0.04199385  0.16152717

# %% [markdown]
# And store the change in a column called `change` and have a brief look.

# %%
# your code here
chiefs$change <- (chiefs$vc16-chiefs$vc15)/chiefs$vc15
tail(chiefs)
# Out:
#    agency                   hom16 hom15 rap16 rap15 rob16 rob15 agg16 agg15
# 57 Tampa PD                 12    21     45    32    258   296   659   772
# 58 Tucson PD                11    16    221   213    537   516  1219   961
# 59 Tulsa PD                 30    27    185   170    459   426  1345  1176
# 60 Virginia Beach PD         8    12    102    75    131   126   136   129
# 61 Washington DC (Metro PD) 68    63    145   128   1491  1527  1102  1211
# 62 Wichita PD               10    13    183   165    289   329  1100   855
#    non16 non15 vc16 vc15 change
# 57 38    75     974 1121 -0.13113292
# 58 NA    NA    1988 1706  0.16529894
# 59 NA    NA    2019 1799  0.12229016
# 60 NA    NA     377  342  0.10233918
# 61 NA    NA    2806 2929 -0.04199385
# 62 61    24    1582 1362  0.16152717

# %% [markdown]
# Compute the so-called 6 number summary (or 5 number if you learned that plus a mean) of the per-city changes in violent crimes using the command `summary()`.

# %%
# your one line here
summary(chiefs$change)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.     NA's
# -0.21576 -0.06063  0.05590  0.04028  0.12882  0.27615        1

# %% [markdown]
# We might reasonably ask about which cities are on the rise and which have had falling crime numbers. We can use a "logical expression" for this. It will return a set of boolean data types, TRUE and FALSE. Compute the logical expression, returning TRUE and FALSE values whether crime is rising or falling between 2015 and 2016 in each city.

# %%
# your one line here
chiefs$change > 0
# Out:
#  [1] FALSE  TRUE FALSE  TRUE  TRUE FALSE  TRUE FALSE  TRUE  TRUE FALSE FALSE
# [13] FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE FALSE  TRUE
# [25]  TRUE  TRUE  TRUE  TRUE  TRUE FALSE FALSE FALSE  TRUE FALSE  TRUE  TRUE
# [37]  TRUE  TRUE FALSE FALSE  TRUE FALSE FALSE FALSE    NA  TRUE  TRUE FALSE
# [49] FALSE  TRUE  TRUE FALSE FALSE  TRUE  TRUE FALSE FALSE  TRUE  TRUE  TRUE
# [61] FALSE  TRUE

# %% [markdown]
# Notice we have an NA or missing value. One city is missing data. We can ask which crime statitics are NA by simply asking...

# %%
is.na(chiefs$change)
# Out:
#  [1] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [13] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [25] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [37] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE FALSE FALSE FALSE
# [49] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [61] FALSE FALSE

# %% [markdown]
# Use this vector of logical data (TRUE and FALSE values) to subset the `chiefs` data frame and keep just the row(s) that have a problem. Identify the problem.

# %%
# your one line here
chiefs[is.na(chiefs$change), ]
# Out:
#    agency       hom16 hom15 rap16 rap15 rob16 rob15 agg16 agg15 non16 non15
# 45 Phoenix PD 4 78    52    NA    509   NA    1502  NA    2450  NA    NA
#    vc16 vc15 change
# 45 NA   4513 NA

# %% [markdown]
# Use the same logical vector and find out how many cities had missing data using the `sum()` command.

# %%
# your one line here
sum(is.na(chiefs$change))
# Out:
# [1] 1

# %% [markdown]
# Because there is an NA, we have to remove it if we want sum() to return a non-missing value. We know there are missing values and we've looked at where they came from. It's safe, then, to consider dropping them out when considering how many ups and downs we have.

# %%
sum(chiefs$change > 0, na.rm=TRUE)
# Out:
# [1] 36

# %% [markdown]
# And let's have a look. Use a histogram to show the data. What's a histogram again?

# %%
# your one line here
hist(chiefs$change)
# Out:
# Plot with title “Histogram of chiefs$change”

# %% [markdown]
# What do you see? Change the breaks and tell me what you see.

# %%
hist(chiefs$change,breaks=20)
# Out:
# Plot with title “Histogram of chiefs$change”

# %% [markdown]
# **Tell me what you see**
#
# It looks like a bimodal distribution of values, with one peak in the low positive and the other in a low negative.

# %% [markdown]
# Now, let's use that logical mask again, this time to find our errant row with missing data and to create a data frame that leaves it out. Call it `chiefs2`. One hint: Using "!" turns TRUE to FALSE and FALSE to TRUE. So the expression below identifies just those rows that *are not* NA's.

# %%
!is.na(chiefs$change)
# Out:
#  [1]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
# [13]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
# [25]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
# [37]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE
# [49]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
# [61]  TRUE  TRUE

# %%
# your one line here
chiefs2 <- chiefs[!is.na(chiefs$change), ]

# %%
dim(chiefs2)
# Out:
# [1] 61 14

# %% [markdown]
# Find those cities with a relative increase greater than 10%...

# %%
# your one line here
chiefs2[chiefs2$change > 0.1, ]
# Out:
#    agency                    hom16 hom15 rap16 rap15 rob16 rob15 agg16 agg15
# 4  Aurora PD                  10     7    127   149   287   205   390   317
# 5  Austin PD                  12     9    328   387   516   446  1114   942
# 9  Charlotte-Mecklenburg PD   25    27    144   140   912   770  2080  1658
# 10 Chicago PD                316   211    677   643  5176  4050  2751  2298
# 16 El Paso PD                  8     9    158   154   221   189   967   848
# 17 Fairfax County PD           7     5     17    12   216   196    98    80
# 19 Fresno PD                  17    25     52    65   548   473   946   754
# 21 Houston PD                158   144    612   368  4764  4772  6059  4916
# 22 Indianapolis PD            61    53    232   228  1523  1249  1586  1427
# 24 Las Vegas Metropolitan PD  90    56    612   551  1597  1340   956   766
# 27 Los Angeles PD            134   129   1226  1148  4990  4258  7728  6348
# 28 Louisville Metro PD        54    35     70    80   766   695  1452  1255
# 37 New Orleans PD             67    92    299   152   686   622   949   786
# 50 Salt Lake City PD           3     4     96    76   269   218   402   345
# 51 San Antonio PD             70    51    572   509  1051   915  3418  2530
# 54 San Jose PD                25    11    220   178   583   581  1091   930
# 58 Tucson PD                  11    16    221   213   537   516  1219   961
# 59 Tulsa PD                   30    27    185   170   459   426  1345  1176
# 60 Virginia Beach PD           8    12    102    75   131   126   136   129
# 62 Wichita PD                 10    13    183   165   289   329  1100   855
#    non16 non15 vc16  vc15  change
# 4    18   15     814   678 0.2005900
# 5    NA   NA    1970  1784 0.1042601
# 9   179  109    3161  2595 0.2181118
# 10 1321  875    8920  7202 0.2385448
# 16   NA   NA    1354  1200 0.1283333
# 17   NA   NA     338   293 0.1535836
# 19   95   77    1563  1317 0.1867882
# 21  197  148   11593 10200 0.1365686
# 22  245  190    3402  2957 0.1504904
# 24  436  347    3255  2713 0.1997788
# 27  450  451   14078 11883 0.1847177
# 28  199  135    2342  2065 0.1341404
# 37  150  125    2001  1652 0.2112591
# 50   NA   NA     770   643 0.1975117
# 51   NA   NA    5111  4005 0.2761548
# 54   NA   NA    1919  1700 0.1288235
# 58   NA   NA    1988  1706 0.1652989
# 59   NA   NA    2019  1799 0.1222902
# 60   NA   NA     377   342 0.1023392
# 62   61   24    1582  1362 0.1615272

# %% [markdown]
# ... and an increase less than 10%.

# %%
# your one line here
chiefs2[chiefs2$change < 0.1, ]
# Out:
#    agency                            hom16 hom15 rap16 rap15 rob16 rob15 agg16
# 1  Albuquerque PD                     34    25   156   199    753   861  1601
# 2  Arlington PD                       13     4   123   117    245   248   668
# 3  Atlanta PD                         57    45    72    72   1005  1003  1028
# 6  Baltimore County PD                16    14   141   134    583   652   823
# 7  Baltimore PD                      137   144   137   141   2373  2041  2344
# 8  Boston PD                          22    13   116    98    659   661  1269
# 11 Cincinnati PD                      35    41   127   125    574   598   350
# 12 Cleveland PD                       47    50   218   286   1285  1394  1075
# 13 Columbus Police                    39    48   347   350    963  1105   678
# 14 Dallas PD                          83    69   381   405   2150  2008  2160
# 15 Denver PD                          19    20   249   309    578   561  1364
# 18 Fort Worth PD                      34    28   182   215    585   486  1368
# 20 Honolulu PD 2                       8     6    95   133    276   260   365
# 23 Jacksonville Sheriff's Dept        59    50   172   187    771   673  1407
# 25 Long Beach PD                      15    13   109    96    540   466   744
# 26 Los Angeles County Sheriff's Dept 110    85   399   365   2202  1915  4371
# 29 Memphis PD                        106    65   170   191   1547  1413  2512
# 30 Mesa PD                            11     6   117   142    190   219   605
# 31 Miami PD                           27    43    42    35    671   768  1182
# 32 Miami-Dade PD                      37    39   227   191    680   821  1955
# 33 Milwaukee PD                       54    73   176   161   1528  1687  2625
# 34 Montgomery Co PD                    8    15   171   135    313   296   294
# 35 Nashville PD                       34    31   296   286    869   813  2502
# 36 Nassau County PD 1                  3     4    16    27    215   192   276
# 38 New York City PD                  161   172   696   648   7337  7627  9926
# 39 Newark PD                          45    40    46    46    621   891   519
# 40 Oakland PD                         28    41   101   129   1486  1735  1306
# 41 Oklahoma City PD 2                 19    14   158   160    376   322  1123
# 42 Omaha NE PD                        12    20   121   100    242   329   730
# 43 Orlando PD 3                       65     8    84    92    240   270   804
# 44 Philadelphia PD                   122   115   634   679   2896  3113  3722
# 46 Pittsburgh PD                      30    21    52    37    435   391   626
# 47 Prince George’s County PD          48    28    40    48    569   522   163
# 48 Raleigh PD                          6     7    55    50    289   322   386
# 49 Sacramento PD                      13    25    39    53    533   569  1131
# 52 San Diego PD                       24    17   297   253    723   659  1600
# 53 San Francisco PD                   26    24   163   174   1497  1896  1302
# 55 Seattle PD                         12     9    79    51    762   788  1032
# 56 St. Louis Metro PD                 87    92   140   127    811   832  1738
# 57 Tampa PD                           12    21    45    32    258   296   659
# 61 Washington DC (Metro PD)           68    63   145   128   1491  1527  1102
#    agg15 non16 non15 vc16  vc15  change
# 1  1608  125     NA   2544  2693 -0.05532863
# 2   600   NA     NA   1049   969  0.08255934
# 3  1064  161    161   2162  2184 -0.01007326
# 6  1193   20     18   1563  1993 -0.21575514
# 7  2285  318    282   4991  4611  0.08241162
# 8  1399   93    100   2066  2171 -0.04836481
# 11  344  189    227   1086  1108 -0.01985560
# 12 1118  411    388   2625  2848 -0.07830056
# 13  854  160    161   2027  2357 -0.14000849
# 14 1860   NA     NA   4774  4342  0.09949332
# 15 1290  103     95   2210  2180  0.01376147
# 18 1396   59     65   2169  2125  0.02070588
# 20  364   19     33    744   763 -0.02490170
# 23 1539  162    180   2409  2449 -0.01633320
# 25  727   NA     NA   1408  1302  0.08141321
# 26 4124   NA     NA   7082  6489  0.09138542
# 29 2354  452    796   4335  4023  0.07755406
# 30  652   NA     NA    923  1019 -0.09421001
# 31 1226   NA     NA   1922  2072 -0.07239382
# 32 2111  119    122   2899  3162 -0.08317521
# 33 2420  267    298   4383  4341  0.00967519
# 34  450   15     NA    786   896 -0.12276786
# 35 2358  109    103   3701  3488  0.06106651
# 36  260   15      9    510   483  0.05590062
# 38 9401  349    442  18120 17848  0.01523980
# 39  436   79    107   1231  1413 -0.12880396
# 40 1264  145    168   2921  3169 -0.07825813
# 41 1030   NA     NA   1676  1526  0.09829620
# 42  758   60     65   1105  1207 -0.08450704
# 43  900   35     40   1193  1270 -0.06062992
# 44 3741  463    399   7374  7648 -0.03582636
# 46  601  239    238   1143  1050  0.08857143
# 47  167   83     68    820   765  0.07189542
# 48  443   35     31    736   822 -0.10462287
# 49 1185   NA     NA   1716  1832 -0.06331878
# 52 1916   NA     NA   2644  2845 -0.07065026
# 53 1358   69     63   2988  3452 -0.13441483
# 55  978   29     37   1885  1826  0.03231106
# 56 1755  980   1086   2776  2806 -0.01069138
# 57  772   38     75    974  1121 -0.13113292
# 61 1211   NA     NA   2806  2929 -0.04199385

# %% [markdown]
# Now, use chiefs2 to create a the percentage change for all the cities taken together. What do you see?

# %%
# put your code here
#
mean(chiefs2$change) # a 4% increase in violent crime between 2015 and 2016.
# Out:
# [1] 0.04027925

# %% [markdown]
# National trends
# ---------------
#
# The data we've been looking captures just 2015-2016 -- well six months of 2015 and six months of 2016. It is a bit dangerous to make interpretations based on just one year's data. Crime fluctuates naturally from year to year and those fluctuations are best understood in terms of larger overall trends. To assess these trends, we appeal to the Uniform Crime Reports compiled by the FBI. You can [access the raw data here.](https://www.icpsr.umich.edu/icpsrweb/NACJD/series/57) I have a nicer form of the data for you already [loaded on Github](https://github.com/cocteau/lede2018/raw/master/data/ucr_crime_1975_2015.csv).
#
# Let's bring it into R.

# %%
ucr <- read.csv("https://github.com/cocteau/lede2018/raw/master/data/ucr_crime_1975_2015.csv",as.is=TRUE)
head(ucr)
# Out:
#   ORI     year department_name   total_pop homs_sum rape_sum rob_sum
# 1 NM00101 1975 Albuquerque, N.M. 286238     30      181       819
# 2 TX22001 1975 Arlington, Texas  112478      5       28       113
# 3 GAAPD00 1975 Atlanta           490584    185      443      3887
# 4 CO00101 1975 Aurora, Colo.     116656      7       44       171
# 5 TX22701 1975 Austin, Texas     300400     33      190       529
# 6 MDBPD00 1975 Baltimore         864100    259      463      9055
#   agg_ass_sum violent_crime months_reported violent_per_100k homs_per_100k
# 1 1353         2383         12               832.5240        10.480789
# 2  132          278         12               247.1594         4.445314
# 3 3518         8033         12              1637.4362        37.710158
# 4  389          611         12               523.7622         6.000549
# 5  463         1215         12               404.4607        10.985353
# 6 6309        16086         12              1861.5901        29.973383
#   rape_per_100k rob_per_100k agg_ass_per_100k source url
# 1 63.23409       286.1255    472.6836         NA     NA
# 2 24.89376       100.4641    117.3563         NA     NA
# 3 90.30054       792.3210    717.1045         NA     NA
# 4 37.71773       146.5848    333.4591         NA     NA
# 5 63.24900       176.0985    154.1278         NA     NA
# 6 53.58176      1047.9111    730.1238         NA     NA

# %% [markdown]
# We've seen simple summaries and graphics for quantitative data. We have various tabular summaries for quantitative data. Here we "table()" the column of years for UCR reports to see how many cities are reporting per year.

# %%
table(ucr$year)
# Out:
# 1975 1976 1977 1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989 1990
#   69   69   69   69   69   69   69   69   69   69   69   69   69   69   69   69
# 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004 2005 2006
#   69   69   69   69   69   69   69   69   69   69   69   69   69   69   69   69
# 2007 2008 2009 2010 2011 2012 2013 2014 2015
#   69   69   69   69   69   69   69   69   69

# %% [markdown]
# And here we are doing the same by department, to see how many years worth of data we have for each department. It's very regular!

# %%
table(ucr$department_name)
# Out:
#           Albuquerque, N.M.            Arlington, Texas
#                          41                          41
#                     Atlanta               Aurora, Colo.
#                          41                          41
#               Austin, Texas                   Baltimore
#                          41                          41
#       Baltimore County, Md.                      Boston
#                          41                          41
#               Buffalo, N.Y. Charlotte-Mecklenburg, N.C.
#                          41                          41
#                     Chicago                  Cincinnati
#                          41                          41
#                   Cleveland              Columbus, Ohio
#                          41                          41
#                      Dallas                      Denver
#                          41                          41
#                     Detroit              El Paso, Texas
#                          41                          41
#         Fairfax County, Va.           Fort Worth, Texas
#                          41                          41
#              Fresno, Calif.                    Honolulu
#                          41                          41
#                     Houston                Indianapolis
#                          41                          41
#          Jacksonville, Fla.            Kansas City, Mo.
#                          41                          41
#                   Las Vegas          Long Beach, Calif.
#                          41                          41
#                 Los Angeles  Los Angeles County, Calif.
#                          41                          41
#             Louisville, Ky.              Memphis, Tenn.
#                          41                          41
#                 Mesa, Ariz.                       Miami
#                          41                          41
#     Miami-Dade County, Fla.                   Milwaukee
#                          41                          41
#                 Minneapolis      Montgomery County, Md.
#                          41                          41
#            Nashville, Tenn.         Nassau County, N.Y.
#                          41                          41
#                    National                 New Orleans
#                          41                          41
#               New York City                Newark, N.J.
#                          41                          41
#             Oakland, Calif.               Oklahoma City
#                          41                          41
#                 Omaha, Neb.               Orlando, Fla.
#                          41                          41
#                Philadelphia                     Phoenix
#                          41                          41
#                  Pittsburgh              Portland, Ore.
#                          41                          41
# Prince George's County, Md.               Raleigh, N.C.
#                          41                          41
#          Sacramento, Calif.              Salt Lake City
#                          41                          41
#                 San Antonio                   San Diego
#                          41                          41
#               San Francisco                    San Jose
#                          41                          41
#                     Seattle              St. Louis, Mo.
#                          41                          41
#        Suffolk County, N.Y.                 Tampa, Fla.
#                          41                          41
#               Tucson, Ariz.                Tulsa, Okla.
#                          41                          41
#         Virginia Beach, Va.            Washington, D.C.
#                          41                          41
#               Wichita, Kan.
#                          41

# %%
summary(ucr$violent_crime)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#     154    3015    5136   29632    9058 1932274      35

# %% [markdown]
# The summary shows a few missing values of violent crime numbers. Pull out the cities missing data on `violent_crime`.

# %%
# your code here
ucr[is.na(ucr$violent_crime), ]
# Out:
#      ORI     year department_name       total_pop homs_sum rape_sum rob_sum
# 31   KY05680 1975 Louisville, Ky.           NA     NA       NA        NA
# 100  KY05680 1976 Louisville, Ky.           NA     NA       NA        NA
# 169  KY05680 1977 Louisville, Ky.           NA     NA       NA        NA
# 238  KY05680 1978 Louisville, Ky.           NA     NA       NA        NA
# 307  KY05680 1979 Louisville, Ky.           NA     NA       NA        NA
# 376  KY05680 1980 Louisville, Ky.           NA     NA       NA        NA
# 445  KY05680 1981 Louisville, Ky.           NA     NA       NA        NA
# 514  KY05680 1982 Louisville, Ky.           NA     NA       NA        NA
# 583  KY05680 1983 Louisville, Ky.           NA     NA       NA        NA
# 652  KY05680 1984 Louisville, Ky.           NA     NA       NA        NA
# 721  KY05680 1985 Louisville, Ky.           NA     NA       NA        NA
# 790  KY05680 1986 Louisville, Ky.           NA     NA       NA        NA
# 859  KY05680 1987 Louisville, Ky.           NA     NA       NA        NA
# 922  FL01602 1988 Jacksonville, Fla.    645024    187      573      4299
# 928  KY05680 1988 Louisville, Ky.           NA     NA       NA        NA
# 961  FL02902 1988 Tampa, Fla.           293732     NA       NA        NA
# 997  KY05680 1989 Louisville, Ky.           NA     NA       NA        NA
# 1066 KY05680 1990 Louisville, Ky.           NA     NA       NA        NA
# 1135 KY05680 1991 Louisville, Ky.           NA     NA       NA        NA
# 1204 KY05680 1992 Louisville, Ky.           NA     NA       NA        NA
# 1273 KY05680 1993 Louisville, Ky.           NA     NA       NA        NA
# 1342 KY05680 1994 Louisville, Ky.           NA     NA       NA        NA
# 1411 KY05680 1995 Louisville, Ky.           NA     NA       NA        NA
# 1480 KY05680 1996 Louisville, Ky.           NA     NA       NA        NA
# 1530 OHCIP00 1997 Cincinnati            360875     NA       NA        NA
# 1549 KY05680 1997 Louisville, Ky.           NA     NA       NA        NA
# 1599 OHCIP00 1998 Cincinnati            344828     NA       NA        NA
# 1618 KY05680 1998 Louisville, Ky.           NA     NA       NA        NA
# 1687 KY05680 1999 Louisville, Ky.           NA     NA       NA        NA
# 1756 KY05680 2000 Louisville, Ky.           NA     NA       NA        NA
# 1825 KY05680 2001 Louisville, Ky.           NA     NA       NA        NA
# 1894 KY05680 2002 Louisville, Ky.           NA     NA       NA        NA
# 2767 MD00301 2015 Baltimore County, Md. 828871     NA       NA        NA
# 2773 OHCLP00 2015 Cleveland             388655     NA       NA        NA
# 2812 OR02602 2015 Portland, Ore.        615672     NA       NA        NA
#      agg_ass_sum violent_crime months_reported violent_per_100k homs_per_100k
# 31   NA          NA            NA              NA                     NA
# 100  NA          NA            NA              NA                     NA
# 169  NA          NA            NA              NA                     NA
# 238  NA          NA            NA              NA                     NA
# 307  NA          NA            NA              NA                     NA
# 376  NA          NA            NA              NA                     NA
# 445  NA          NA            NA              NA                     NA
# 514  NA          NA            NA              NA                     NA
# 583  NA          NA            NA              NA                     NA
# 652  NA          NA            NA              NA                     NA
# 721  NA          NA            NA              NA                     NA
# 790  NA          NA            NA              NA                     NA
# 859  NA          NA            NA              NA                     NA
# 922  NA          NA             0              NA               28.99117
# 928  NA          NA            NA              NA                     NA
# 961  NA          NA             0              NA                     NA
# 997  NA          NA            NA              NA                     NA
# 1066 NA          NA            NA              NA                     NA
# 1135 NA          NA            NA              NA                     NA
# 1204 NA          NA            NA              NA                     NA
# 1273 NA          NA            NA              NA                     NA
# 1342 NA          NA            NA              NA                     NA
# 1411 NA          NA            NA              NA                     NA
# 1480 NA          NA            NA              NA                     NA
# 1530 NA          NA             0              NA                     NA
# 1549 NA          NA            NA              NA                     NA
# 1599 NA          NA             0              NA                     NA
# 1618 NA          NA            NA              NA                     NA
# 1687 NA          NA            NA              NA                     NA
# 1756 NA          NA            NA              NA                     NA
# 1825 NA          NA            NA              NA                     NA
# 1894 NA          NA            NA              NA                     NA
# 2767 NA          NA            NA              NA                     NA
# 2773 NA          NA            NA              NA                     NA
# 2812 NA          NA            NA              NA                     NA
#      rape_per_100k rob_per_100k agg_ass_per_100k source
# 31        NA             NA     NA               NA
# 100       NA             NA     NA               NA
# 169       NA             NA     NA               NA
# 238       NA             NA     NA               NA
# 307       NA             NA     NA               NA
# 376       NA             NA     NA               NA
# 445       NA             NA     NA               NA
# 514       NA             NA     NA               NA
# 583       NA             NA     NA               NA
# 652       NA             NA     NA               NA
# 721       NA             NA     NA               NA
# 790       NA             NA     NA               NA
# 859       NA             NA     NA               NA
# 922  88.8339       666.4868     NA               Florida Times-Union
# 928       NA             NA     NA               NA
# 961       NA             NA     NA               NA
# 997       NA             NA     NA               NA
# 1066      NA             NA     NA               NA
# 1135      NA             NA     NA               NA
# 1204      NA             NA     NA               NA
# 1273      NA             NA     NA               NA
# 1342      NA             NA     NA               NA
# 1411      NA             NA     NA               NA
# 1480      NA             NA     NA               NA
# 1530      NA             NA     NA               NA
# 1549      NA             NA     NA               NA
# 1599      NA             NA     NA               NA
# 1618      NA             NA     NA               NA
# 1687      NA             NA     NA               NA
# 1756      NA             NA     NA               NA
# 1825      NA             NA     NA               NA
# 1894      NA             NA     NA               NA
# 2767      NA             NA     NA
# 2773      NA             NA     NA
# 2812      NA             NA     NA
#      url
# 31   NA
# 100  NA
# 169  NA
# 238  NA
# 307  NA
# 376  NA
# 445  NA
# 514  NA
# 583  NA
# 652  NA
# 721  NA
# 790  NA
# 859  NA
# 922  "City's crime up slower than '87", March 12, 1989, Florida Times-Union
# 928  NA
# 961  NA
# 997  NA
# 1066 NA
# 1135 NA
# 1204 NA
# 1273 NA
# 1342 NA
# 1411 NA
# 1480 NA
# 1530 NA
# 1549 NA
# 1599 NA
# 1618 NA
# 1687 NA
# 1756 NA
# 1825 NA
# 1894 NA
# 2767
# 2773
# 2812

# %%
ucr2 <- ucr[!is.na(ucr$violent_crime), ]

# %%
dim(ucr2)
# Out:
# [1] 2794   17

# %% [markdown]
# Just to make sure we understand the columns, violent crime is meant to be a combination of homicides, rapes, robberies and aggravated assault. Let's form that sum and compare it to the violent crime column in the data set. Useful, but not necessary hint: The command `all()` takes a logical vector and asks "Are all the values TRUE?". If so, it returns TRUE.
#
# So, create a vector from the data set that represents the category of violent crimes, compare that total to the `violent_crime` column in the data set, testing if they are all equal to each other.

# %%
ucr2$testing <- ucr2$homs_sum+ucr2$rape_sum+ucr2$rob_sum+ucr2$agg_ass_sum

# %%
# your code here
all(ucr2$testing != ucr2$violent_crime) #there appears to be some NA values preventing a TRUE return.
# Out:
# [1] FALSE

# %% [markdown]
# Just to be cleaer, let's look at places that have huge crime numbers...

# %%
ucr[ucr$violent_crime > 1000000,]
# Out:
#       ORI year department_name total_pop homs_sum rape_sum rob_sum agg_ass_sum
# NA    NA    NA NA              NA           NA    NA       NA      NA
# 41    NA  1975 National        NA        20510    NA       NA      NA
# NA.1  NA    NA NA              NA           NA    NA       NA      NA
# 110   NA  1976 National        NA        18780    NA       NA      NA
# NA.2  NA    NA NA              NA           NA    NA       NA      NA
# 179   NA  1977 National        NA        19120    NA       NA      NA
# NA.3  NA    NA NA              NA           NA    NA       NA      NA
# 248   NA  1978 National        NA        19560    NA       NA      NA
# NA.4  NA    NA NA              NA           NA    NA       NA      NA
# 317   NA  1979 National        NA        21460    NA       NA      NA
# NA.5  NA    NA NA              NA           NA    NA       NA      NA
# 386   NA  1980 National        NA        23040    NA       NA      NA
# NA.6  NA    NA NA              NA           NA    NA       NA      NA
# 455   NA  1981 National        NA        22520    NA       NA      NA
# NA.7  NA    NA NA              NA           NA    NA       NA      NA
# 524   NA  1982 National        NA        21010    NA       NA      NA
# NA.8  NA    NA NA              NA           NA    NA       NA      NA
# 593   NA  1983 National        NA        19308    NA       NA      NA
# NA.9  NA    NA NA              NA           NA    NA       NA      NA
# 662   NA  1984 National        NA        18692    NA       NA      NA
# NA.10 NA    NA NA              NA           NA    NA       NA      NA
# 731   NA  1985 National        NA        18976    NA       NA      NA
# NA.11 NA    NA NA              NA           NA    NA       NA      NA
# 800   NA  1986 National        NA        20613    NA       NA      NA
# NA.12 NA    NA NA              NA           NA    NA       NA      NA
# 869   NA  1987 National        NA        20096    NA       NA      NA
# NA.13 NA    NA NA              NA           NA    NA       NA      NA
# NA.14 NA    NA NA              NA           NA    NA       NA      NA
# 938   NA  1988 National        NA        20675    NA       NA      NA
# NA.15 NA    NA NA              NA           NA    NA       NA      NA
# ⋮     ⋮   ⋮    ⋮               ⋮         ⋮        ⋮        ⋮       ⋮
# NA.24 NA    NA NA              NA           NA    NA       NA      NA
# NA.25 NA    NA NA              NA           NA    NA       NA      NA
# 1559  NA  1997 National        NA        18208    NA       NA      NA
# NA.26 NA    NA NA              NA           NA    NA       NA      NA
# NA.27 NA    NA NA              NA           NA    NA       NA      NA
# 1628  NA  1998 National        NA        16974    NA       NA      NA
# NA.28 NA    NA NA              NA           NA    NA       NA      NA
# 1697  NA  1999 National        NA        15522    NA       NA      NA
# NA.29 NA    NA NA              NA           NA    NA       NA      NA
# 1766  NA  2000 National        NA        15586    NA       NA      NA
# NA.30 NA    NA NA              NA           NA    NA       NA      NA
# 1835  NA  2001 National        NA        16037    NA       NA      NA
# NA.31 NA    NA NA              NA           NA    NA       NA      NA
# 1904  NA  2002 National        NA        16229    NA       NA      NA
# 1973  NA  2003 National        NA        16528    NA       NA      NA
# 2042  NA  2004 National        NA        16148    NA       NA      NA
# 2111  NA  2005 National        NA        16740    NA       NA      NA
# 2180  NA  2006 National        NA        17309    NA       NA      NA
# 2249  NA  2007 National        NA        17128    NA       NA      NA
# 2318  NA  2008 National        NA        16465    NA       NA      NA
# 2387  NA  2009 National        NA        15399    NA       NA      NA
# 2456  NA  2010 National        NA        14722    NA       NA      NA
# 2525  NA  2011 National        NA        14661    NA       NA      NA
# 2594  NA  2012 National        NA        14827    NA       NA      NA
# 2663  NA  2013 National        NA        14319    NA       NA      NA
# 2732  NA  2014 National        NA        14164    NA       NA      NA
# NA.32 NA    NA NA              NA           NA    NA       NA      NA
# NA.33 NA    NA NA              NA           NA    NA       NA      NA
# 2801  NA  2015 National        NA        15696    NA       NA      NA
# NA.34 NA    NA NA              NA           NA    NA       NA      NA
#       violent_crime months_reported violent_per_100k homs_per_100k
# NA         NA       NA                 NA              NA
# 41    1039710       NA              487.8             9.6
# NA.1       NA       NA                 NA              NA
# 110   1004210       NA              467.8             8.7
# NA.2       NA       NA                 NA              NA
# 179   1029580       NA              475.9             8.8
# NA.3       NA       NA                 NA              NA
# 248   1085550       NA              497.8             9.0
# NA.4       NA       NA                 NA              NA
# 317   1208030       NA              548.9             9.8
# NA.5       NA       NA                 NA              NA
# 386   1344520       NA              596.6            10.2
# NA.6       NA       NA                 NA              NA
# 455   1361820       NA              593.5             9.8
# NA.7       NA       NA                 NA              NA
# 524   1322390       NA              570.8             9.1
# NA.8       NA       NA                 NA              NA
# 593   1258087       NA              538.1             8.3
# NA.9       NA       NA                 NA              NA
# 662   1273282       NA              539.9             7.9
# NA.10      NA       NA                 NA              NA
# 731   1327767       NA              558.1             8.0
# NA.11      NA       NA                 NA              NA
# 800   1489169       NA              620.1             8.6
# NA.12      NA       NA                 NA              NA
# 869   1483999       NA              612.5             8.3
# NA.13      NA       NA                 NA              NA
# NA.14      NA       NA                 NA              NA
# 938   1566221       NA              640.6             8.5
# NA.15      NA       NA                 NA              NA
# ⋮     ⋮             ⋮               ⋮                ⋮
# NA.24      NA       NA                 NA             NA
# NA.25      NA       NA                 NA             NA
# 1559  1636096       NA              611.0            6.8
# NA.26      NA       NA                 NA             NA
# NA.27      NA       NA                 NA             NA
# 1628  1533887       NA              567.6            6.3
# NA.28      NA       NA                 NA             NA
# 1697  1426044       NA              523.0            5.7
# NA.29      NA       NA                 NA             NA
# 1766  1425486       NA              506.5            5.5
# NA.30      NA       NA                 NA             NA
# 1835  1439480       NA              504.5            5.6
# NA.31      NA       NA                 NA             NA
# 1904  1423677       NA              494.4            5.6
# 1973  1383676       NA              475.8            5.7
# 2042  1360088       NA              463.2            5.5
# 2111  1390745       NA              469.0            5.6
# 2180  1435123       NA              479.3            5.8
# 2249  1422970       NA              471.8            5.7
# 2318  1394461       NA              458.6            5.4
# 2387  1325896       NA              431.9            5.0
# 2456  1251248       NA              404.5            4.8
# 2525  1206031       NA              387.1            4.7
# 2594  1214464       NA              386.9            4.7
# 2663  1168298       NA              369.1            4.5
# 2732  1153022       NA              361.6            4.4
# NA.32      NA       NA                 NA             NA
# NA.33      NA       NA                 NA             NA
# 2801  1197704       NA              372.6            4.9
# NA.34      NA       NA                 NA             NA
#       rape_per_100k rob_per_100k agg_ass_per_100k source url
# NA    NA            NA           NA               NA     NA
# 41    NA            NA           NA               NA     NA
# NA.1  NA            NA           NA               NA     NA
# 110   NA            NA           NA               NA     NA
# NA.2  NA            NA           NA               NA     NA
# 179   NA            NA           NA               NA     NA
# NA.3  NA            NA           NA               NA     NA
# 248   NA            NA           NA               NA     NA
# NA.4  NA            NA           NA               NA     NA
# 317   NA            NA           NA               NA     NA
# NA.5  NA            NA           NA               NA     NA
# 386   NA            NA           NA               NA     NA
# NA.6  NA            NA           NA               NA     NA
# 455   NA            NA           NA               NA     NA
# NA.7  NA            NA           NA               NA     NA
# 524   NA            NA           NA               NA     NA
# NA.8  NA            NA           NA               NA     NA
# 593   NA            NA           NA               NA     NA
# NA.9  NA            NA           NA               NA     NA
# 662   NA            NA           NA               NA     NA
# NA.10 NA            NA           NA               NA     NA
# 731   NA            NA           NA               NA     NA
# NA.11 NA            NA           NA               NA     NA
# 800   NA            NA           NA               NA     NA
# NA.12 NA            NA           NA               NA     NA
# 869   NA            NA           NA               NA     NA
# NA.13 NA            NA           NA               NA     NA
# NA.14 NA            NA           NA               NA     NA
# 938   NA            NA           NA               NA     NA
# NA.15 NA            NA           NA               NA     NA
# ⋮     ⋮             ⋮            ⋮                ⋮      ⋮
# NA.24 NA            NA           NA               NA     NA
# NA.25 NA            NA           NA               NA     NA
# 1559  NA            NA           NA               NA     NA
# NA.26 NA            NA           NA               NA     NA
# NA.27 NA            NA           NA               NA     NA
# 1628  NA            NA           NA               NA     NA
# NA.28 NA            NA           NA               NA     NA
# 1697  NA            NA           NA               NA     NA
# NA.29 NA            NA           NA               NA     NA
# 1766  NA            NA           NA               NA     NA
# NA.30 NA            NA           NA               NA     NA
# 1835  NA            NA           NA               NA     NA
# NA.31 NA            NA           NA               NA     NA
# 1904  NA            NA           NA               NA     NA
# 1973  NA            NA           NA               NA     NA
# 2042  NA            NA           NA               NA     NA
# 2111  NA            NA           NA               NA     NA
# 2180  NA            NA           NA               NA     NA
# 2249  NA            NA           NA               NA     NA
# 2318  NA            NA           NA               NA     NA
# 2387  NA            NA           NA               NA     NA
# 2456  NA            NA           NA               NA     NA
# 2525  NA            NA           NA               NA     NA
# 2594  NA            NA           NA               NA     NA
# 2663  NA            NA           NA               NA     NA
# 2732  NA            NA           NA               NA     NA
# NA.32 NA            NA           NA               NA     NA
# NA.33 NA            NA           NA               NA     NA
# 2801  NA            NA           NA               NA     NA
# NA.34 NA            NA           NA               NA     NA

# %% [markdown]
# Or, using dplyr2 verbs...

# %%
filter(ucr,violent_crime>100000)
# Out:
#    ORI     year department_name total_pop homs_sum rape_sum rob_sum agg_ass_sum
# 1  NA      1975 National             NA   20510      NA         NA     NA
# 2  NY03030 1975 New York City   7422506    1645    3866      83190  43481
# 3  NA      1976 National             NA   18780      NA         NA     NA
# 4  NY03030 1976 New York City   7530493    1622    3400      86183  42948
# 5  NA      1977 National             NA   19120      NA         NA     NA
# 6  NY03030 1977 New York City   7481613    1557    3899      74404  42056
# 7  NA      1978 National             NA   19560      NA         NA     NA
# 8  NY03030 1978 New York City   7242886    1503    3882      74029  43271
# 9  NA      1979 National             NA   21460      NA         NA     NA
# 10 NY03030 1979 New York City   7109420    1733    3875      82572  44203
# 11 NA      1980 National             NA   23040      NA         NA     NA
# 12 NY03030 1980 New York City   7035348    1812    3711     100550  43476
# 13 NA      1981 National             NA   22520      NA         NA     NA
# 14 NY03030 1981 New York City   7070429    1826    3862     107475  43783
# 15 NA      1982 National             NA   21010      NA         NA     NA
# 16 NY03030 1982 New York City   7096559    1668    3547      95944  42784
# 17 NA      1983 National             NA   19308      NA         NA     NA
# 18 NY03030 1983 New York City   7100063    1622    3662      84043  43326
# 19 NA      1984 National             NA   18692      NA         NA     NA
# 20 NY03030 1984 New York City   7167121    1450    3829      79541  47472
# 21 NA      1985 National             NA   18976      NA         NA     NA
# 22 NY03030 1985 New York City   7183984    1384    3880      79532  50356
# 23 NA      1986 National             NA   20613      NA         NA     NA
# 24 NY03030 1986 New York City   7179609    1582    3536      80827  57306
# 25 NA      1987 National             NA   20096      NA         NA     NA
# 26 NY03030 1987 New York City   7284319    1672    3507      78890  64244
# 27 NA      1988 National             NA   20675      NA         NA     NA
# 28 NY03030 1988 New York City   7346352    1896    3412      86578  71030
# 29 NA      1989 National             NA   21500      NA         NA     NA
# 30 NY03030 1989 New York City   7369454    1905    3254      93377  70951
# ⋮  ⋮       ⋮    ⋮               ⋮         ⋮        ⋮        ⋮       ⋮
# 33 NA      1991 National             NA   24703      NA        NA      NA
# 34 NY03030 1991 New York City   7350023    2154    2892     98512   66832
# 35 NA      1992 National             NA   23760      NA        NA      NA
# 36 NY03030 1992 New York City   7375097    1995    2815     91239   63529
# 37 NA      1993 National             NA   24526      NA        NA      NA
# 38 NY03030 1993 New York City   7347257    1946    2818     86001   62778
# 39 NA      1994 National             NA   23326      NA        NA      NA
# 40 NY03030 1994 New York City   7336224    1561    2666     72540   59755
# 41 NA      1995 National             NA   21606      NA        NA      NA
# 42 NY03030 1995 New York City   7319546    1177    2317     59278   51251
# 43 NA      1996 National             NA   19645      NA        NA      NA
# 44 NA      1997 National             NA   18208      NA        NA      NA
# 45 NA      1998 National             NA   16974      NA        NA      NA
# 46 NA      1999 National             NA   15522      NA        NA      NA
# 47 NA      2000 National             NA   15586      NA        NA      NA
# 48 NA      2001 National             NA   16037      NA        NA      NA
# 49 NA      2002 National             NA   16229      NA        NA      NA
# 50 NA      2003 National             NA   16528      NA        NA      NA
# 51 NA      2004 National             NA   16148      NA        NA      NA
# 52 NA      2005 National             NA   16740      NA        NA      NA
# 53 NA      2006 National             NA   17309      NA        NA      NA
# 54 NA      2007 National             NA   17128      NA        NA      NA
# 55 NA      2008 National             NA   16465      NA        NA      NA
# 56 NA      2009 National             NA   15399      NA        NA      NA
# 57 NA      2010 National             NA   14722      NA        NA      NA
# 58 NA      2011 National             NA   14661      NA        NA      NA
# 59 NA      2012 National             NA   14827      NA        NA      NA
# 60 NA      2013 National             NA   14319      NA        NA      NA
# 61 NA      2014 National             NA   14164      NA        NA      NA
# 62 NA      2015 National             NA   15696      NA        NA      NA
#    violent_crime months_reported violent_per_100k homs_per_100k rape_per_100k
# 1  1039710       NA               487.800          9.60000            NA
# 2   132182       12              1780.827         22.16233      52.08483
# 3  1004210       NA               467.800          8.70000            NA
# 4   134153       12              1781.464         21.53909      45.14977
# 5  1029580       NA               475.900          8.80000            NA
# 6   121916       12              1629.542         20.81102      52.11443
# 7  1085550       NA               497.800          9.00000            NA
# 8   122685       12              1693.869         20.75140      53.59742
# 9  1208030       NA               548.900          9.80000            NA
# 10  132383       12              1862.079         24.37611      54.50515
# 11 1344520       NA               596.600         10.20000            NA
# 12  149549       12              2125.680         25.75566      52.74792
# 13 1361820       NA               593.500          9.80000            NA
# 14  156946       12              2219.752         25.82587      54.62186
# 15 1322390       NA               570.800          9.10000            NA
# 16  143943       12              2028.349         23.50435      49.98197
# 17 1258087       NA               538.100          8.30000            NA
# 18  132653       12              1868.336         22.84487      51.57701
# 19 1273282       NA               539.900          7.90000            NA
# 20  132292       12              1845.818         20.23128      53.42452
# 21 1327767       NA               558.100          8.00000            NA
# 22  135152       12              1881.296         19.26508      54.00903
# 23 1489169       NA               620.100          8.60000            NA
# 24  143251       12              1995.248         22.03463      49.25059
# 25 1483999       NA               612.500          8.30000            NA
# 26  148313       12              2036.059         22.95342      48.14451
# 27 1566221       NA               640.600          8.50000            NA
# 28  162916       12              2217.645         25.80873      46.44482
# 29 1646037       NA               666.900          8.70000            NA
# 30  169487       12              2299.858         25.84995      44.15524
# ⋮  ⋮             ⋮               ⋮                ⋮             ⋮
# 33 1911767       NA               758.200          9.80000            NA
# 34  170390       12              2318.224         29.30603      39.34682
# 35 1932274       NA               757.700          9.30000            NA
# 36  159578       12              2163.741         27.05049      38.16899
# 37 1926017       NA               747.100          9.50000            NA
# 38  153543       12              2089.800         26.48608      38.35445
# 39 1857670       NA               713.600          9.00000            NA
# 40  136522       12              1860.930         21.27798      36.34022
# 41 1798792       NA               684.500          8.20000            NA
# 42  114023       12              1557.788         16.08023      31.65497
# 43 1688540       NA               636.600          7.40000            NA
# 44 1636096       NA               611.000          6.80000            NA
# 45 1533887       NA               567.600          6.30000            NA
# 46 1426044       NA               523.000          5.70000            NA
# 47 1425486       NA               506.500          5.50000            NA
# 48 1439480       NA               504.500          5.60000            NA
# 49 1423677       NA               494.400          5.60000            NA
# 50 1383676       NA               475.800          5.70000            NA
# 51 1360088       NA               463.200          5.50000            NA
# 52 1390745       NA               469.000          5.60000            NA
# 53 1435123       NA               479.300          5.80000            NA
# 54 1422970       NA               471.800          5.70000            NA
# 55 1394461       NA               458.600          5.40000            NA
# 56 1325896       NA               431.900          5.00000            NA
# 57 1251248       NA               404.500          4.80000            NA
# 58 1206031       NA               387.100          4.70000            NA
# 59 1214464       NA               386.900          4.70000            NA
# 60 1168298       NA               369.100          4.50000            NA
# 61 1153022       NA               361.600          4.40000            NA
# 62 1197704       NA               372.600          4.90000            NA
#    rob_per_100k agg_ass_per_100k source url
# 1         NA          NA         NA     NA
# 2  1120.7805    585.7995         NA     NA
# 3         NA          NA         NA     NA
# 4  1144.4536    570.3212         NA     NA
# 5         NA          NA         NA     NA
# 6   994.4914    562.1248         NA     NA
# 7         NA          NA         NA     NA
# 8  1022.0926    597.4276         NA     NA
# 9         NA          NA         NA     NA
# 10 1161.4450    621.7525         NA     NA
# 11        NA          NA         NA     NA
# 12 1429.2115    617.9652         NA     NA
# 13        NA          NA         NA     NA
# 14 1520.0634    619.2411         NA     NA
# 15        NA          NA         NA     NA
# 16 1351.9792    602.8837         NA     NA
# 17        NA          NA         NA     NA
# 18 1183.6937    610.2199         NA     NA
# 19        NA          NA         NA     NA
# 20 1109.8041    662.3580         NA     NA
# 21        NA          NA         NA     NA
# 22 1107.0737    700.9481         NA     NA
# 23        NA          NA         NA     NA
# 24 1125.7855    798.1772         NA     NA
# 25        NA          NA         NA     NA
# 26 1083.0113    881.9493         NA     NA
# 27        NA          NA         NA     NA
# 28 1178.5169    966.8744         NA     NA
# 29        NA          NA         NA     NA
# 30 1267.0817    962.7715         NA     NA
# ⋮  ⋮            ⋮                ⋮      ⋮
# 33        NA          NA         NA     NA
# 34 1340.2951    909.2761         NA     NA
# 35        NA          NA         NA     NA
# 36 1237.1227    861.3988         NA     NA
# 37        NA          NA         NA     NA
# 38 1170.5185    854.4413         NA     NA
# 39        NA          NA         NA     NA
# 40  988.7921    814.5198         NA     NA
# 41        NA          NA         NA     NA
# 42  809.8590    700.1937         NA     NA
# 43        NA          NA         NA     NA
# 44        NA          NA         NA     NA
# 45        NA          NA         NA     NA
# 46        NA          NA         NA     NA
# 47        NA          NA         NA     NA
# 48        NA          NA         NA     NA
# 49        NA          NA         NA     NA
# 50        NA          NA         NA     NA
# 51        NA          NA         NA     NA
# 52        NA          NA         NA     NA
# 53        NA          NA         NA     NA
# 54        NA          NA         NA     NA
# 55        NA          NA         NA     NA
# 56        NA          NA         NA     NA
# 57        NA          NA         NA     NA
# 58        NA          NA         NA     NA
# 59        NA          NA         NA     NA
# 60        NA          NA         NA     NA
# 61        NA          NA         NA     NA
# 62        NA          NA         NA     NA

# %% [markdown]
# The extra `NA` rows correspond to the missing data entries in Violent Crime that we found above. R will (bless its heart) just turn the entire row into missing values. That can be annoying in cases when we want `NA`'s to be removed from the table. In the next lecture we'll see some higher-level tools that will do this for us, but for now we can just add to our logical expression and take only those rows where the crime count is not missing and is bigger than 1000000. We join two logical conditions with an "&" for "and" and "|" for "or".

# %%
# your code here
ucr[ucr$violent_crime>1000000 & !is.na(ucr$violent_crime), ]
# Out:
#      ORI year department_name total_pop homs_sum rape_sum rob_sum agg_ass_sum
# 41   NA  1975 National        NA        20510    NA       NA      NA
# 110  NA  1976 National        NA        18780    NA       NA      NA
# 179  NA  1977 National        NA        19120    NA       NA      NA
# 248  NA  1978 National        NA        19560    NA       NA      NA
# 317  NA  1979 National        NA        21460    NA       NA      NA
# 386  NA  1980 National        NA        23040    NA       NA      NA
# 455  NA  1981 National        NA        22520    NA       NA      NA
# 524  NA  1982 National        NA        21010    NA       NA      NA
# 593  NA  1983 National        NA        19308    NA       NA      NA
# 662  NA  1984 National        NA        18692    NA       NA      NA
# 731  NA  1985 National        NA        18976    NA       NA      NA
# 800  NA  1986 National        NA        20613    NA       NA      NA
# 869  NA  1987 National        NA        20096    NA       NA      NA
# 938  NA  1988 National        NA        20675    NA       NA      NA
# 1007 NA  1989 National        NA        21500    NA       NA      NA
# 1076 NA  1990 National        NA        23438    NA       NA      NA
# 1145 NA  1991 National        NA        24703    NA       NA      NA
# 1214 NA  1992 National        NA        23760    NA       NA      NA
# 1283 NA  1993 National        NA        24526    NA       NA      NA
# 1352 NA  1994 National        NA        23326    NA       NA      NA
# 1421 NA  1995 National        NA        21606    NA       NA      NA
# 1490 NA  1996 National        NA        19645    NA       NA      NA
# 1559 NA  1997 National        NA        18208    NA       NA      NA
# 1628 NA  1998 National        NA        16974    NA       NA      NA
# 1697 NA  1999 National        NA        15522    NA       NA      NA
# 1766 NA  2000 National        NA        15586    NA       NA      NA
# 1835 NA  2001 National        NA        16037    NA       NA      NA
# 1904 NA  2002 National        NA        16229    NA       NA      NA
# 1973 NA  2003 National        NA        16528    NA       NA      NA
# 2042 NA  2004 National        NA        16148    NA       NA      NA
# 2111 NA  2005 National        NA        16740    NA       NA      NA
# 2180 NA  2006 National        NA        17309    NA       NA      NA
# 2249 NA  2007 National        NA        17128    NA       NA      NA
# 2318 NA  2008 National        NA        16465    NA       NA      NA
# 2387 NA  2009 National        NA        15399    NA       NA      NA
# 2456 NA  2010 National        NA        14722    NA       NA      NA
# 2525 NA  2011 National        NA        14661    NA       NA      NA
# 2594 NA  2012 National        NA        14827    NA       NA      NA
# 2663 NA  2013 National        NA        14319    NA       NA      NA
# 2732 NA  2014 National        NA        14164    NA       NA      NA
# 2801 NA  2015 National        NA        15696    NA       NA      NA
#      violent_crime months_reported violent_per_100k homs_per_100k rape_per_100k
# 41   1039710       NA              487.8             9.6          NA
# 110  1004210       NA              467.8             8.7          NA
# 179  1029580       NA              475.9             8.8          NA
# 248  1085550       NA              497.8             9.0          NA
# 317  1208030       NA              548.9             9.8          NA
# 386  1344520       NA              596.6            10.2          NA
# 455  1361820       NA              593.5             9.8          NA
# 524  1322390       NA              570.8             9.1          NA
# 593  1258087       NA              538.1             8.3          NA
# 662  1273282       NA              539.9             7.9          NA
# 731  1327767       NA              558.1             8.0          NA
# 800  1489169       NA              620.1             8.6          NA
# 869  1483999       NA              612.5             8.3          NA
# 938  1566221       NA              640.6             8.5          NA
# 1007 1646037       NA              666.9             8.7          NA
# 1076 1820127       NA              729.6             9.4          NA
# 1145 1911767       NA              758.2             9.8          NA
# 1214 1932274       NA              757.7             9.3          NA
# 1283 1926017       NA              747.1             9.5          NA
# 1352 1857670       NA              713.6             9.0          NA
# 1421 1798792       NA              684.5             8.2          NA
# 1490 1688540       NA              636.6             7.4          NA
# 1559 1636096       NA              611.0             6.8          NA
# 1628 1533887       NA              567.6             6.3          NA
# 1697 1426044       NA              523.0             5.7          NA
# 1766 1425486       NA              506.5             5.5          NA
# 1835 1439480       NA              504.5             5.6          NA
# 1904 1423677       NA              494.4             5.6          NA
# 1973 1383676       NA              475.8             5.7          NA
# 2042 1360088       NA              463.2             5.5          NA
# 2111 1390745       NA              469.0             5.6          NA
# 2180 1435123       NA              479.3             5.8          NA
# 2249 1422970       NA              471.8             5.7          NA
# 2318 1394461       NA              458.6             5.4          NA
# 2387 1325896       NA              431.9             5.0          NA
# 2456 1251248       NA              404.5             4.8          NA
# 2525 1206031       NA              387.1             4.7          NA
# 2594 1214464       NA              386.9             4.7          NA
# 2663 1168298       NA              369.1             4.5          NA
# 2732 1153022       NA              361.6             4.4          NA
# 2801 1197704       NA              372.6             4.9          NA
#      rob_per_100k agg_ass_per_100k source url
# 41   NA           NA               NA     NA
# 110  NA           NA               NA     NA
# 179  NA           NA               NA     NA
# 248  NA           NA               NA     NA
# 317  NA           NA               NA     NA
# 386  NA           NA               NA     NA
# 455  NA           NA               NA     NA
# 524  NA           NA               NA     NA
# 593  NA           NA               NA     NA
# 662  NA           NA               NA     NA
# 731  NA           NA               NA     NA
# 800  NA           NA               NA     NA
# 869  NA           NA               NA     NA
# 938  NA           NA               NA     NA
# 1007 NA           NA               NA     NA
# 1076 NA           NA               NA     NA
# 1145 NA           NA               NA     NA
# 1214 NA           NA               NA     NA
# 1283 NA           NA               NA     NA
# 1352 NA           NA               NA     NA
# 1421 NA           NA               NA     NA
# 1490 NA           NA               NA     NA
# 1559 NA           NA               NA     NA
# 1628 NA           NA               NA     NA
# 1697 NA           NA               NA     NA
# 1766 NA           NA               NA     NA
# 1835 NA           NA               NA     NA
# 1904 NA           NA               NA     NA
# 1973 NA           NA               NA     NA
# 2042 NA           NA               NA     NA
# 2111 NA           NA               NA     NA
# 2180 NA           NA               NA     NA
# 2249 NA           NA               NA     NA
# 2318 NA           NA               NA     NA
# 2387 NA           NA               NA     NA
# 2456 NA           NA               NA     NA
# 2525 NA           NA               NA     NA
# 2594 NA           NA               NA     NA
# 2663 NA           NA               NA     NA
# 2732 NA           NA               NA     NA
# 2801 NA           NA               NA     NA

# %% [markdown]
# ... ah, there are national totals in this data set. So let's have a look at one municipality. Let's pull the data aside and make some plots!

# %%
miami <- filter(ucr,department_name=="Miami")
miami
# Out:
#    ORI     year department_name total_pop homs_sum rape_sum rob_sum agg_ass_sum
# 1  FL01306 1975 Miami           350742     98      178      2657    3280
# 2  FL01306 1976 Miami           338721     84      145      2313    2630
# 3  FL01306 1977 Miami           333713     84      178      2447    2637
# 4  FL01306 1978 Miami           330060     96      207      2832    3137
# 5  FL01306 1979 Miami           362840    134      261      3390    3040
# 6  FL01306 1980 Miami           335718    220      325      6890    4039
# 7  FL01306 1981 Miami           356734    210      382      6196    4423
# 8  FL01306 1982 Miami           365506    190      349      5123    4301
# 9  FL01306 1983 Miami           374769    144      365      4719    4556
# 10 FL01306 1984 Miami           400646    170      273      5705    4780
# 11 FL01306 1985 Miami           385892    131      284      5768    5003
# 12 FL01306 1986 Miami           396374    148      221      5767    5540
# 13 FL01306 1987 Miami           385089    128      202      5594    5385
# 14 FL01306 1988 Miami           389720    146      411      6398    6006
# 15 FL01306 1989 Miami           381206    132      285      7289    6387
# 16 FL01306 1990 Miami           358548    129      299      8172    7007
# 17 FL01306 1991 Miami           367945    125      236      8477    6582
# 18 FL01306 1992 Miami           373791    128      272      7065    6480
# 19 FL01306 1993 Miami           372519    127      204      7082    7089
# 20 FL01306 1994 Miami           379980    116      221      5841    6793
# 21 FL01306 1995 Miami           378720    110      198      5676    6943
# 22 FL01306 1996 Miami           384976    124      201      5139    6526
# 23 FL01306 1997 Miami           391766     98      189      4517    6214
# 24 FL01306 1998 Miami           372949     86      140      3797    5482
# 25 FL01306 1999 Miami           373450     63      113      3076    4609
# 26 FL01306 2000 Miami           362470     66      118      3077    4616
# 27 FL01306 2001 Miami           371863     66      118      2719    4307
# 28 FL01306 2002 Miami           379044     65       96      2706    4361
# 29 FL01306 2003 Miami           381651     74      107      2928    4048
# 30 FL01306 2004 Miami           385186     69      102      2367    3923
# 31 FL01306 2005 Miami           388295     54       62      2019    3999
# 32 FL01306 2006 Miami           392934     77      101      2111    3642
# 33 FL01306 2007 Miami           410252     78       57      2537    3447
# 34 FL01306 2008 Miami           427740     63       42      2415    3189
# 35 FL01306 2009 Miami           419205     59       65      2094    2765
# 36 FL01306 2010 Miami           399457     68       46      1856    2909
# 37 FL01306 2011 Miami           404901     68       96      2002    2683
# 38 FL01306 2012 Miami           414327     69       65      2096    2626
# 39 FL01306 2013 Miami           418394     71       96      2216    2562
# 40 FL01306 2014 Miami           421996     81      110      1790    2492
# 41 FL01306 2015 Miami           437969     75       80      1681    2637
#    violent_crime months_reported violent_per_100k homs_per_100k rape_per_100k
# 1   6213         12              1771.388         27.94077       50.749554
# 2   5172         12              1526.920         24.79917       42.808093
# 3   5346         12              1601.975         25.17133       53.339247
# 4   6272         12              1900.261         29.08562       62.715870
# 5   6825         12              1880.994         36.93088       71.932532
# 6  11474         12              3417.749         65.53119       96.807440
# 7  11211         12              3142.678         58.86739      107.082588
# 8   9963         12              2725.810         51.98273       95.484069
# 9   9784         12              2610.675         38.42367       97.393328
# 10 10928         12              2727.595         42.43147       68.139954
# 11 11186         12              2898.739         33.94732       73.595721
# 12 11676         12              2945.703         37.33847       55.755423
# 13 11309         12              2936.724         33.23907       52.455406
# 14 12961          0              3325.721         37.46279      105.460330
# 15 14093         12              3696.951         34.62695       74.762727
# 16 15607         12              4352.834         35.97845       83.391903
# 17 15420         12              4190.844         33.97247       64.140021
# 18 13945         12              3730.694         34.24374       72.767937
# 19 14502         12              3892.956         34.09222       54.762307
# 20 12971         12              3413.601         30.52792       58.160956
# 21 12927         12              3413.340         29.04520       52.281369
# 22 11990         12              3114.480         32.20980       52.211047
# 23 11018         12              2812.393         25.01493       48.243084
# 24  9505         12              2548.606         23.05945       37.538645
# 25  7861         12              2104.967         16.86973       30.258401
# 26  7877         12              2173.145         18.20840       32.554418
# 27  7210         12              1938.886         17.74847       31.732116
# 28  7228         12              1906.903         17.14840       25.326875
# 29  7157         12              1875.273         19.38944       28.036085
# 30  6461         12              1677.371         17.91342       26.480713
# 31  6134         12              1579.727         13.90695       15.967241
# 32  5931         12              1509.414         19.59617       25.704062
# 33  6119         12              1491.522         19.01270       13.893899
# 34  5709         12              1334.689         14.72857        9.819049
# 35  4983         12              1188.679         14.07426       15.505540
# 36  4879         12              1221.408         17.02311       11.515632
# 37  4849         12              1197.577         16.79423       23.709499
# 38  4856         12              1172.021         16.65351       15.688092
# 39  4945         12              1181.900         16.96965       22.944880
# 40  4473         12              1059.963         19.19449       26.066598
# 41  4473         NA              1021.305         17.12450       18.266133
#    rob_per_100k agg_ass_per_100k source
# 1   757.5369     935.1603        NA
# 2   682.8629     776.4502        NA
# 3   733.2648     790.2000        NA
# 4   858.0258     950.4333        NA
# 5   934.2961     837.8349        NA
# 6  2052.3177    1203.0931        NA
# 7  1736.8684    1239.8594        NA
# 8  1401.6186    1176.7249        NA
# 9  1259.1757    1215.6822        NA
# 10 1423.9503    1193.0732        NA
# 11 1494.7187    1296.4767        NA
# 12 1454.9390    1397.6699        NA
# 13 1452.6512    1398.3780        NA
# 14 1641.6915    1541.1064        Miami Herald
# 15 1912.0895    1675.4721        NA
# 16 2279.1927    1954.2711        NA
# 17 2303.8769    1788.8543        NA
# 18 1890.0937    1733.5891        NA
# 19 1901.1111    1902.9902        NA
# 20 1537.1862    1787.7257        NA
# 21 1498.7326    1833.2805        NA
# 22 1334.8884    1695.1706        NA
# 23 1152.9842    1586.1509        NA
# 24 1018.1017    1469.9061        NA
# 25  823.6712    1234.1679        NA
# 26  848.8978    1273.4847        NA
# 27  731.1833    1158.2222        NA
# 28  713.9013    1150.5261        NA
# 29  767.1931    1060.6549        NA
# 30  614.5083    1018.4690        NA
# 31  519.9655    1029.8871        NA
# 32  537.2404     926.8732        NA
# 33  618.4004     840.2153        NA
# 34  564.5953     745.5464        NA
# 35  499.5169     659.5818        NA
# 36  464.6307     728.2386        NA
# 37  494.4419     662.6311        NA
# 38  505.8806     633.7989        NA
# 39  529.6443     612.3415        NA
# 40  424.1746     590.5269        NA
# 41  383.8171     602.0974        Crime in the U.S. 2015
#    url
# 1  NA
# 2  NA
# 3  NA
# 4  NA
# 5  NA
# 6  NA
# 7  NA
# 8  NA
# 9  NA
# 10 NA
# 11 NA
# 12 NA
# 13 NA
# 14 "MAJOR CRIMES UP MOST IN 4 YEARS," March 11, 1989, Miami Herald via Nexis
# 15 NA
# 16 NA
# 17 NA
# 18 NA
# 19 NA
# 20 NA
# 21 NA
# 22 NA
# 23 NA
# 24 NA
# 25 NA
# 26 NA
# 27 NA
# 28 NA
# 29 NA
# 30 NA
# 31 NA
# 32 NA
# 33 NA
# 34 NA
# 35 NA
# 36 NA
# 37 NA
# 38 NA
# 39 NA
# 40 NA
# 41 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls

# %%
plot(miami$year,miami$violent_per_100k)
# Out:
# plot without title

# %%
options(repr.plot.width=8,repr.plot.height=4)

plot(miami$year,miami$violent_per_100k,xlab="Year",ylab="Violent Crimes per 100K People",type="l",main="Crime Rate in Miami")
points(miami$year,miami$violent_per_100k,pch=19,cex=0.5)
# Out:
# Plot with title “Crime Rate in Miami”

# %% [markdown]
# Create a plot for a city larger than Miami and a plot for a city smaller than Miami.

# %%
# code to pick your city
#
portland <- filter(ucr,department_name=="Portland, Ore.")
portland
# Out:
#    ORI     year department_name total_pop homs_sum rape_sum rob_sum agg_ass_sum
# 1  OR02602 1975 Portland, Ore.  373126    48       287      1843    1898
# 2  OR02602 1976 Portland, Ore.  379818    39       322      1913    2030
# 3  OR02602 1977 Portland, Ore.  385230    41       337      1703    1892
# 4  OR02602 1978 Portland, Ore.  362497    34       371      1774    1838
# 5  OR02602 1979 Portland, Ore.  406525    39       435      1787    2297
# 6  OR02602 1980 Portland, Ore.  364419    46       364      2249    2298
# 7  OR02602 1981 Portland, Ore.  369518    38       403      3072    2939
# 8  OR02602 1982 Portland, Ore.  369796    36       392      2811    3245
# 9  OR02602 1983 Portland, Ore.  371706    36       377      2964    3502
# 10 OR02602 1984 Portland, Ore.  367055    34       370      3042    3962
# 11 OR02602 1985 Portland, Ore.  367571    43       469      3508    4614
# 12 OR02602 1986 Portland, Ore.  368439    46       438      3887    4433
# 13 OR02602 1987 Portland, Ore.  390845    66       407      3667    4623
# 14 OR02602 1988 Portland, Ore.  387659    45       372      3632    4637
# 15 OR02602 1989 Portland, Ore.  425788    38       415      2667    4932
# 16 OR02602 1990 Portland, Ore.  437319    33       424      2541    4838
# 17 OR02602 1991 Portland, Ore.  449671    53       464      2723    4881
# 18 OR02602 1992 Portland, Ore.  458132    46       490      2686    5167
# 19 OR02602 1993 Portland, Ore.  454889    58       479      2305    5603
# 20 OR02602 1994 Portland, Ore.  463072    50       400      2344    6014
# 21 OR02602 1995 Portland, Ore.  458623    43       426      2298    6066
# 22 OR02602 1996 Portland, Ore.  467906    51       402      2057    5325
# 23 OR02602 1997 Portland, Ore.  473696    46       356      1948    5250
# 24 OR02602 1998 Portland, Ore.  488813    26       361      1639    4681
# 25 OR02602 1999 Portland, Ore.  508984    35       340      1418    4501
# 26 OR02602 2000 Portland, Ore.  529121    19       369      1446    3864
# 27 OR02602 2001 Portland, Ore.  537081    21       305      1267    2963
# 28 OR02602 2002 Portland, Ore.  544604    20       354      1294    2844
# 29 OR02602 2003 Portland, Ore.  545271    27       310      1367    2732
# 30 OR02602 2004 Portland, Ore.  543838    29       313      1287    2405
# 31 OR02602 2005 Portland, Ore.  540389    20       325      1137    2376
# 32 OR02602 2006 Portland, Ore.  542174    20       293      1297    2262
# 33 OR02602 2007 Portland, Ore.  538133    22       280      1289    2110
# 34 OR02602 2008 Portland, Ore.  553023    26       250      1132    2037
# 35 OR02602 2009 Portland, Ore.  560908    19       252      1037    1797
# 36 OR02602 2010 Portland, Ore.  583776    22       230      1005    1794
# 37 OR02602 2011 Portland, Ore.  589991    20       258       917    1842
# 38 OR02602 2012 Portland, Ore.  598037    20       231       950    1892
# 39 OR02602 2013 Portland, Ore.  609136    14       234       917    1776
# 40 OR02602 2014 Portland, Ore.  615672    26       262       847    1776
# 41 OR02602 2015 Portland, Ore.  615672    NA        NA        NA      NA
#    violent_crime months_reported violent_per_100k homs_per_100k rape_per_100k
# 1  4076          12              1092.3924        12.864287      76.91772
# 2  4304          12              1133.1743        10.268076      84.77745
# 3  3973          12              1031.3319        10.642992      87.48021
# 4  4017          12              1108.1471         9.379388     102.34567
# 5  4558          12              1121.2103         9.593506     107.00449
# 6  4957          12              1360.2474        12.622833      99.88502
# 7  6452          12              1746.0584        10.283667     109.06099
# 8  6484          12              1753.3992         9.735097     106.00439
# 9  6879          12              1850.6562         9.685074     101.42424
# 10 7408          12              2018.2262         9.262917     100.80233
# 11 8634          12              2348.9339        11.698420     127.59440
# 12 8804          12              2389.5407        12.485106     118.87992
# 13 8763          12              2242.0653        16.886490     104.13335
# 14 8686          12              2240.6290        11.608140      95.96063
# 15 8052          12              1891.0819         8.924629      97.46634
# 16 7836          12              1791.8270         7.545979      96.95440
# 17 8121          12              1805.9870        11.786395     103.18655
# 18 8389          12              1831.1316        10.040774     106.95607
# 19 8445          12              1856.4969        12.750363     105.30041
# 20 8808          12              1902.0800        10.797457      86.37966
# 21 8833          12              1925.9828         9.375893      92.88675
# 22 7835          12              1674.4816        10.899625      85.91469
# 23 7600          12              1604.4045         9.710869      75.15369
# 24 6707          12              1372.0994         5.319007      73.85237
# 25 6294          12              1236.5811         6.876444      66.79974
# 26 5698          12              1076.8803         3.590861      69.73830
# 27 4556          12               848.2892         3.910025      56.78845
# 28 4512          12               828.4919         3.672393      65.00136
# 29 4436          12               813.5404         4.951666      56.85246
# 30 4034          12               741.7650         5.332470      57.55390
# 31 3858          12               713.9302         3.701038      60.14186
# 32 3872          12               714.1619         3.688853      54.04169
# 33 3701          12               687.7482         4.088209      52.03175
# 34 3445          12               622.9397         4.701432      45.20608
# 35 3105          12               553.5667         3.387365      44.92715
# 36 3051          12               522.6320         3.768569      39.39867
# 37 3037          12               514.7536         3.389882      43.72948
# 38 3093          12               517.1921         3.344275      38.62637
# 39 2941          12               482.8150         2.298337      38.41507
# 40 2911          12               472.8167         4.223028      42.55513
# 41   NA          NA                     NA               NA            NA
#    rob_per_100k agg_ass_per_100k source url
# 1   493.9350     508.6754        NA     NA
# 2   503.6623     534.4665        NA     NA
# 3   442.0736     491.1352        NA     NA
# 4   489.3834     507.0387        NA     NA
# 5   439.5794     565.0329        NA     NA
# 6   617.1467     630.5928        NA     NA
# 7   831.3533     795.3604        NA     NA
# 8   760.1488     877.5108        NA     NA
# 9   797.4044     942.1424        NA     NA
# 10  828.7586    1079.4023        NA     NA
# 11  954.3734    1255.2677        NA     NA
# 12 1054.9915    1203.1842        NA     NA
# 13  938.2236    1182.8218        NA     NA
# 14  936.9059    1196.1544        NA     NA
# 15  626.3681    1158.3229        NA     NA
# 16  581.0404    1106.2863        NA     NA
# 17  605.5538    1085.4603        NA     NA
# 18  586.2939    1127.8409        NA     NA
# 19  506.7170    1231.7291        NA     NA
# 20  506.1848    1298.7181        NA     NA
# 21  501.0651    1322.6550        NA     NA
# 22  439.6182    1138.0491        NA     NA
# 23  411.2342    1108.3057        NA     NA
# 24  335.3020     957.6259        NA     NA
# 25  278.5942     884.3107        NA     NA
# 26  273.2834     730.2677        NA     NA
# 27  235.9048     551.6859        NA     NA
# 28  237.6038     522.2143        NA     NA
# 29  250.7010     501.0353        NA     NA
# 30  236.6514     442.2273        NA     NA
# 31  210.4040     439.6833        NA     NA
# 32  239.2221     417.2092        NA     NA
# 33  239.5319     392.0964        NA     NA
# 34  204.6931     368.3391        NA     NA
# 35  184.8788     320.3734        NA     NA
# 36  172.1551     307.3097        NA     NA
# 37  155.4261     312.2082        NA     NA
# 38  158.8530     316.3684        NA     NA
# 39  150.5411     291.5605        NA     NA
# 40  137.5733     288.4653        NA     NA
# 41        NA           NA

# %%
los_angeles <- filter(ucr,department_name=="Los Angeles")
los_angeles
# Out:
#    ORI     year department_name total_pop homs_sum rape_sum rob_sum agg_ass_sum
# 1  CA01942 1975 Los Angeles     2729878    554     1768     14590   13493
# 2  CA01942 1976 Los Angeles     2739100    501     2047     14225   15187
# 3  CA01942 1977 Los Angeles     2785393    576     2339     15246   15515
# 4  CA01942 1978 Los Angeles     2787525    651     2467     17105   16574
# 5  CA01942 1979 Los Angeles     2863412    786     2508     20454   19624
# 6  CA01942 1980 Los Angeles     2952511   1010     2813     25637   21987
# 7  CA01942 1981 Los Angeles     3031090    879     2666     28152   21121
# 8  CA01942 1982 Los Angeles     3101979    849     2706     30029   20373
# 9  CA01942 1983 Los Angeles     3158688    820     2494     29243   20878
# 10 CA01942 1984 Los Angeles     3144256    759     2347     27323   21013
# 11 CA01942 1985 Los Angeles     3186459    777     2318     27938   21799
# 12 CA01942 1986 Los Angeles     3260856    834     2330     29930   33284
# 13 CA01942 1987 Los Angeles     3341726    811     2169     26192   34661
# 14 CA01942 1988 Los Angeles     3402342    736     2006     26182   37812
# 15 CA01942 1989 Los Angeles     3441449    877     1996     31063   43361
# 16 CA01942 1990 Los Angeles     3485398    983     2014     36098   44714
# 17 CA01942 1991 Los Angeles     3558316   1027     1966     39778   47104
# 18 CA01942 1992 Los Angeles     3615355   1094     1872     39508   46445
# 19 CA01942 1993 Los Angeles     3525317   1076     1773     38415   42437
# 20 CA01942 1994 Los Angeles     3550381    845     1554     30817   39886
# 21 CA01942 1995 Los Angeles     3466211    849     1590     29134   38945
# 22 CA01942 1996 Los Angeles     3498139    711     1463     25189   35477
# 23 CA01942 1997 Los Angeles     3541309    576     1413     20506   34043
# 24 CA01942 1998 Los Angeles     3621680    426     1395     15835   31545
# 25 CA01942 1999 Los Angeles     3650138    425     1288     14411   30716
# 26 CA01942 2000 Los Angeles     3694820    550     1459     15527   32705
# 27 CA01942 2001 Los Angeles     3763486    588     1409     17166   33080
# 28 CA01942 2002 Los Angeles     3830561    654     1415     17197   32429
# 29 CA01942 2003 Los Angeles     3838838    515     1226     16577   30506
# 30 CA01942 2004 Los Angeles     3864018    518     1131     14181   26956
# 31 CA01942 2005 Los Angeles     3871077    489     1105     13797   16376
# 32 CA01942 2006 Los Angeles     3879455    480     1059     14353   14634
# 33 CA01942 2007 Los Angeles     3870487    395     1004     13481   12926
# 34 CA01942 2008 Los Angeles     3850920    384      949     13422   11798
# 35 CA01942 2009 Los Angeles     3848776    312      903     12217   10638
# 36 CA01942 2010 Los Angeles     3792621    293      923     10924    9344
# 37 CA01942 2011 Los Angeles     3837207    297      828     10077    8843
# 38 CA01942 2012 Los Angeles     3855122    299      936      8983    8329
# 39 CA01942 2013 Los Angeles     3878725    251      764      7885    7624
# 40 CA01942 2014 Los Angeles     3906772    260     1126      7949    9836
# 41 CA01942 2015 Los Angeles     3962726    282     2209      8952   13713
#    violent_crime months_reported violent_per_100k homs_per_100k rape_per_100k
# 1  30405         12              1113.7860        20.293947     64.76480
# 2  31960         12              1166.8066        18.290679     74.73258
# 3  33676         12              1209.0215        20.679308     83.97379
# 4  36797         12              1320.0599        23.354051     88.50145
# 5  43372         12              1514.6965        27.449770     87.58781
# 6  51447         12              1742.4829        34.208171     95.27484
# 7  52818         12              1742.5415        28.999469     87.95516
# 8  53957         12              1739.4380        27.369624     87.23463
# 9  53435         12              1691.6834        25.960145     78.95683
# 10 51442         12              1636.0627        24.139256     74.64405
# 11 52832         12              1658.0160        24.384434     72.74533
# 12 66378         12              2035.6005        25.576106     71.45363
# 13 63833         12              1910.1805        24.268896     64.90658
# 14 66736         12              1961.4724        21.632158     58.95939
# 15 77297         12              2246.0597        25.483452     57.99883
# 16 83809         12              2404.5747        28.203379     57.78393
# 17 89875         12              2525.7734        28.861967     55.25085
# 18 88919         12              2459.4818        30.259822     51.77915
# 19 83701         12              2374.2829        30.522078     50.29335
# 20 73102         12              2058.9903        23.800263     43.76995
# 21 70518         12              2034.4405        24.493604     45.87141
# 22 62840         12              1796.3837        20.325093     41.82224
# 23 56538         12              1596.5283        16.265172     39.90050
# 24 49201         12              1358.5132        11.762497     38.51804
# 25 46840         12              1283.2392        11.643395     35.28634
# 26 50241         12              1359.7685        14.885705     39.48772
# 27 52243         12              1388.1545        15.623813     37.43869
# 28 51695         12              1349.5412        17.073217     36.93976
# 29 48824         12              1271.8432        13.415518     31.93675
# 30 42786         12              1107.2930        13.405735     29.27005
# 31 31767         12               820.6243        12.632143     28.54503
# 32 30526         12               786.8631        12.372872     27.29765
# 33 27806         12               718.4109        10.205434     25.93989
# 34 26553         12               689.5235         9.971643     24.64346
# 35 24070         12               625.3936         8.106473     23.46200
# 36 21484         12               566.4684         7.725528     24.33673
# 37 20045         12               522.3852         7.740005     21.57819
# 38 18547         12               481.1002         7.755915     24.27939
# 39 16524         12               426.0163         6.471199     19.69719
# 40 19171         12               490.7120         6.655111     28.82175
# 41 25156         NA               634.8155         7.116313     55.74445
#    rob_per_100k agg_ass_per_100k source
# 1   534.4561     494.2712        NA
# 2   519.3312     554.4522        NA
# 3   547.3554     557.0130        NA
# 4   613.6268     594.5776        NA
# 5   714.3226     685.3362        NA
# 6   868.3118     744.6882        NA
# 7   928.7748     696.8120        NA
# 8   968.0594     656.7743        NA
# 9   925.7958     660.9706        NA
# 10  868.9814     668.2980        NA
# 11  876.7726     684.1136        NA
# 12  917.8572    1020.7136        NA
# 13  783.7866    1037.2185        NA
# 14  769.5288    1111.3521        NA
# 15  902.6140    1259.9635        NA
# 16 1035.6923    1282.8951        NA
# 17 1117.8883    1323.7723        NA
# 18 1092.7834    1284.6595        NA
# 19 1089.6892    1203.7783        NA
# 20  867.9914    1123.4287        NA
# 21  840.5143    1123.5611        NA
# 22  720.0686    1014.1678        NA
# 23  579.0514     961.3112        NA
# 24  437.2280     871.0046        NA
# 25  394.8070     841.5024        NA
# 26  420.2370     885.1581        NA
# 27  456.1197     878.9723        NA
# 28  448.9421     846.5862        NA
# 29  431.8234     794.6676        NA
# 30  367.0014     697.6158        NA
# 31  356.4124     423.0347        NA
# 32  369.9746     377.2179        NA
# 33  348.3024     333.9631        NA
# 34  348.5401     306.3683        NA
# 35  317.4256     276.3996        NA
# 36  288.0330     246.3732        NA
# 37  262.6129     230.4541        NA
# 38  233.0147     216.0502        NA
# 39  203.2885     196.5594        NA
# 40  203.4672     251.7680        NA
# 41  225.9051     346.0497        Crime in the U.S. 2015
#    url
# 1  NA
# 2  NA
# 3  NA
# 4  NA
# 5  NA
# 6  NA
# 7  NA
# 8  NA
# 9  NA
# 10 NA
# 11 NA
# 12 NA
# 13 NA
# 14 NA
# 15 NA
# 16 NA
# 17 NA
# 18 NA
# 19 NA
# 20 NA
# 21 NA
# 22 NA
# 23 NA
# 24 NA
# 25 NA
# 26 NA
# 27 NA
# 28 NA
# 29 NA
# 30 NA
# 31 NA
# 32 NA
# 33 NA
# 34 NA
# 35 NA
# 36 NA
# 37 NA
# 38 NA
# 39 NA
# 40 NA
# 41 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls

# %%
# code to plot the big city
#
options(repr.plot.width=8,repr.plot.height=4)
plot(los_angeles$year, los_angeles$violent_per_100k,xlab='Year',ylab='Violent Crime per 100K People', type='l', main='Crime Rate in Los Angeles')
points(los_angeles$year,los_angeles$violent_per_100k, pch=19, cex=0.5)
# Out:
# Plot with title “Crime Rate in Los Angeles”

# %%
# code to plot the small city
#
options(repr.plot.width=9,repr.plot.height=4)
plot(portland$year, portland$violent_per_100k, xlab='Year', ylab='Violent Crime per 100K People', type='l', main='Violent Crime in Portland, OR')
points(portland$year,portland$violent_per_100k,pch=19,cex=0.5)
# Out:
# Plot with title “Violent Crime in Portland, OR”

# %% [markdown]
# We'll see some better tools for plotting using ggplot2 next time.
#
# **Short bonus.** See if you can get the data into shape from the Major Cities Chiefs Association for 2016-2017, and update our analysis. The original report that generated the CSV we used [is posted here](https://www.majorcitieschiefs.com/pdf/news/mcca_violent_crime_data_midyear_20162015.pdf). An updated version for 2016-2017 [is posted here](https://www.majorcitieschiefs.com/pdf/news/mcca_violent_crime_report_2017_and_2016_midyear_07312017_update.pdf). Grab the file and see what you can do with it. Remember, I used [Tabula](http://tabula.technology/) to pull the data from the Chiefs' report and convert it to the more usable CSV file we loaded into R. See what you can do to convert the new file and try loading it into R.

# %%
mcca <- read.csv("mcca2017.csv",as.is=TRUE)
head(mcca)
# Out:
#   agency                  hom17 hom16 rap17 rap16 rob17 rob16 agg17 agg16 non17
# 1 Albuquerque Police      32     32   218   193   1310   847  1583  1825  59
# 2 Atlanta Police          37     56   115    73    674   933   973  1032  234
# 3 Aurora Police           18     10   178   201    351   287   549   472  33
# 4 Austin Police           11     15   338   359    482   510  1128  1138  N/A
# 5 Baltimore County Police 19     16   159   151    808   691  1573  1236  16
# 6 Baltimore Police        170   137   158   143   2797  2425  2823  2413  312
#   non16
# 1 40
# 2 194
# 3 21
# 4 N/A
# 5 20
# 6 318

# %%
dim(mcca)
# Out:
# [1] 64 11

# %%
mcca$violent17 = mcca$hom17 + mcca$rap17 + mcca$rob17 + mcca$agg17
mcca$violent16 = mcca$hom16 + mcca$rap16 + mcca$rob16 + mcca$agg16
# Out:
# Error in mcca$hom17 + mcca$rap17: non-numeric argument to binary operator
# Traceback:
